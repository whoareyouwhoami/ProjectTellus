# %% [markdown]
# # 결측치 및 이상치 제거 코드

# %%
import pandas as pd
import numpy as np
pd.set_option('max_columns',999)
pd.set_option('max_rows',200)

import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
import seaborn as sns
sns.set() 
# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina' 
sns.set_style(style='white')
sns.set_context(context ='paper')

import datetime
import os
from functools import reduce
import json

# %%
# Data for training loaded from the database
projects = pd.read_csv('ks-projects-201801.csv')

# %% [markdown]
# ### state 재정의
# 모금 금액이 목표 금액 이상이면 success, 미만이면 failed

# %%
projects['state_new'] = projects.apply(lambda x: 'success' if x['usd_pledged_real'] >= x['usd_goal_real']
                                       else 'failed', axis = 1)

# %% [markdown]
# ### >> deadline & launched --> 펀딩 기간

# %%
projects['launched_year'] = projects.apply(lambda x: x['launched'].split(" ")[0].split("-")[0], axis = 1)
projects['launched_month'] = projects.apply(lambda x: x['launched'].split(" ")[0].split("-")[1], axis = 1)
projects['launched_day'] = projects.apply(lambda x: x['launched'].split(" ")[0].split("-")[2], axis = 1)
projects['launched_date'] = projects.apply(lambda x: x['launched'].split(" ")[0].split("-")[1] + x['launched'].split(" ")[0].split("-")[2], axis = 1)

# %%
projects['deadline_dt'] = projects.apply(lambda x: datetime.datetime.strptime(x['deadline'], "%Y-%m-%d").date(), axis = 1)
projects['launched_dt'] = projects.apply(lambda x: datetime.datetime.strptime(x['launched'].split(" ")[0], "%Y-%m-%d").date(), axis = 1)

# %%
projects['term'] = projects.apply(lambda x: int(str(x['deadline_dt'] - x['launched_dt']).split(" ")[0]), axis = 1)
projects['term_str'] = projects.apply(lambda x: str(x['term']), axis = 1)

# %%
projects.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1  2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2  2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3  2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4  2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
#
#    usd_pledged_real  usd_goal_real state_new launched_year launched_month  \
# 0               0.0        1533.95    failed          2015             08
# 1            2421.0       30000.00    failed          2017             09
# 2             220.0       45000.00    failed          2013             01
# 3               1.0        5000.00    failed          2012             03
# 4            1283.0       19500.00    failed          2015             07
#
#   launched_day launched_date deadline_dt launched_dt  term term_str
# 0           11          0811  2015-10-09  2015-08-11    59       59
# 1           02          0902  2017-11-01  2017-09-02    60       60
# 2           12          0112  2013-02-26  2013-01-12    45       45
# 3           17          0317  2012-04-16  2012-03-17    30       30
# 4           04          0704  2015-08-29  2015-07-04    56       56

# %%
# launch 날짜가 1970년으로 되어있는 row는 삭제
projects_new = projects[lambda x: x['term'] < 100]

# %%
projects_new = projects_new.reset_index().drop(['index'], axis = 1)

# %%
projects_new['term_str'] = projects_new.apply(lambda x: x['term_str'] if len(x['term_str']) != 1
                                             else '0' + x['term_str'], axis = 1)

# %%
# binnarize the dependent variable
projects_new['state_bin'] = projects_new['state_new'].apply(lambda x: 0 if x == 'failed' else 1)

# %%
# 10만원 이하로 펀딩 받는 경우는 지움
projects_fin = projects_new[projects_new['usd_goal_real'] > 100]

# %%
projects_fin = projects_new[projects_new['country'].isin(['US', 'BR', 'CA', 'AU', 'DE', 'FR', 'IT', 'NL', 'ES'])]

# %%
projects_fin = projects_new[projects_new['currency'].isin(['USD', 'GBP', 'EUR', 'CAD', 'AUD'])]

# %% [markdown]
# # Processing the Data into a Trainable data

# %%
# Creating the dataset
train_data = projects_fin[['category', 'main_category', 'currency', 'country', 'usd_goal_real', 'state_bin', 'launched_year', 'launched_month', 'term']].copy()

# %%
train = pd.DataFrame()

# %%
# Assigning a categorical type to categorical varibles and vectorizing the categories for simplification
train['category'] = train_data['category'].astype('category').cat.codes
train['main_category'] = train_data['main_category'].astype('category').cat.codes
train['currency'] = train_data['currency'].astype('category').cat.codes
train['country'] = train_data['country'].astype('category').cat.codes

# %%
# export labes for vectorizing

cat_c = train_data['category'].astype('category')
main_c = train_data['main_category'].astype('category')
curre_c = train_data['currency'].astype('category')
count_c = train_data['country'].astype('category')
cat_d = dict(enumerate(cat_c.cat.categories))
main_d = dict(enumerate(main_c.cat.categories))
curre_d = dict(enumerate(curre_c.cat.categories))
count_d = dict(enumerate(count_c.cat.categories))

cat = {y:x for x,y in cat_d.items()}
main = {y:x for x,y in main_d.items()}
curre = {y:x for x,y in curre_d.items()}
count = {y:x for x,y in count_d.items()}

cat_labels = {'category' : cat, 'main_category' : main, 'currency' : curre, 'country': count}
cat_json = json.dumps(cat_labels)
f = open("cat_labels.json","w")
f.write(cat_json)
f.close()

# %%
with open('cat_labels.json') as json_file:
    data = json.load(json_file)

# %%
data['category']
# Out:
# {'3D Printing': 0,
#  'Academic': 1,
#  'Accessories': 2,
#  'Action': 3,
#  'Animals': 4,
#  'Animation': 5,
#  'Anthologies': 6,
#  'Apparel': 7,
#  'Apps': 8,
#  'Architecture': 9,
#  'Art': 10,
#  'Art Books': 11,
#  'Audio': 12,
#  'Bacon': 13,
#  'Blues': 14,
#  'Calendars': 15,
#  'Camera Equipment': 16,
#  'Candles': 17,
#  'Ceramics': 18,
#  "Children's Books": 19,
#  'Childrenswear': 20,
#  'Chiptune': 21,
#  'Civic Design': 22,
#  'Classical Music': 23,
#  'Comedy': 24,
#  'Comic Books': 25,
#  'Comics': 26,
#  'Community Gardens': 27,
#  'Conceptual Art': 28,
#  'Cookbooks': 29,
#  'Country & Folk': 30,
#  'Couture': 31,
#  'Crafts': 32,
#  'Crochet': 33,
#  'DIY': 34,
#  'DIY Electronics': 35,
#  'Dance': 36,
#  'Design': 37,
#  'Digital Art': 38,
#  'Documentary': 39,
#  'Drama': 40,
#  'Drinks': 41,
#  'Electronic Music': 42,
#  'Embroidery': 43,
#  'Events': 44,
#  'Experimental': 45,
#  'Fabrication Tools': 46,
#  'Faith': 47,
#  'Family': 48,
#  'Fantasy': 49,
#  "Farmer's Markets": 50,
#  'Farms': 51,
#  'Fashion': 52,
#  'Festivals': 53,
#  'Fiction': 54,
#  'Film & Video': 55,
#  'Fine Art': 56,
#  'Flight': 57,
#  'Food': 58,
#  'Food Trucks': 59,
#  'Footwear': 60,
#  'Gadgets': 61,
#  'Games': 62,
#  'Gaming Hardware': 63,
#  'Glass': 64,
#  'Graphic Design': 65,
#  'Graphic Novels': 66,
#  'Hardware': 67,
#  'Hip-Hop': 68,
#  'Horror': 69,
#  'Illustration': 70,
#  'Immersive': 71,
#  'Indie Rock': 72,
#  'Installations': 73,
#  'Interactive Design': 74,
#  'Jazz': 75,
#  'Jewelry': 76,
#  'Journalism': 77,
#  'Kids': 78,
#  'Knitting': 79,
#  'Latin': 80,
#  'Letterpress': 81,
#  'Literary Journals': 82,
#  'Literary Spaces': 83,
#  'Live Games': 84,
#  'Makerspaces': 85,
#  'Metal': 86,
#  'Mixed Media': 87,
#  'Mobile Games': 88,
#  'Movie Theaters': 89,
#  'Music': 90,
#  'Music Videos': 91,
#  'Musical': 92,
#  'Narrative Film': 93,
#  'Nature': 94,
#  'Nonfiction': 95,
#  'Painting': 96,
#  'People': 97,
#  'Performance Art': 98,
#  'Performances': 99,
#  'Periodicals': 100,
#  'Pet Fashion': 101,
#  'Photo': 102,
#  'Photobooks': 103,
#  'Photography': 104,
#  'Places': 105,
#  'Playing Cards': 106,
#  'Plays': 107,
#  'Poetry': 108,
#  'Pop': 109,
#  'Pottery': 110,
#  'Print': 111,
#  'Printing': 112,
#  'Product Design': 113,
#  'Public Art': 114,
#  'Publishing': 115,
#  'Punk': 116,
#  'Puzzles': 117,
#  'Quilts': 118,
#  'R&B': 119,
#  'Radio & Podcasts': 120,
#  'Ready-to-wear': 121,
#  'Residencies': 122,
#  'Restaurants': 123,
#  'Robots': 124,
#  'Rock': 125,
#  'Romance': 126,
#  'Science Fiction': 127,
#  'Sculpture': 128,
#  'Shorts': 129,
#  'Small Batch': 130,
#  'Software': 131,
#  'Sound': 132,
#  'Space Exploration': 133,
#  'Spaces': 134,
#  'Stationery': 135,
#  'Tabletop Games': 136,
#  'Taxidermy': 137,
#  'Technology': 138,
#  'Television': 139,
#  'Textiles': 140,
#  'Theater': 141,
#  'Thrillers': 142,
#  'Translations': 143,
#  'Typography': 144,
#  'Vegan': 145,
#  'Video': 146,
#  'Video Art': 147,
#  'Video Games': 148,
#  'Wearables': 149,
#  'Weaving': 150,
#  'Web': 151,
#  'Webcomics': 152,
#  'Webseries': 153,
#  'Woodworking': 154,
#  'Workshops': 155,
#  'World Music': 156,
#  'Young Adult': 157,
#  'Zines': 158}

# %%
train[['usd_goal_real', 'launched_year', 'launched_month', 'term', 'state']] = train_data[['usd_goal_real', 'launched_year', 'launched_month', 'term', 'state_bin']]

# %%
train['launched_year'] = (train['launched_year']).astype('int8')
train['launched_month'] = (train['launched_month']).astype('int8')

# %% [markdown]
# # Feature Selection
# Result: all columns seems to be important

# %%
x = train.iloc[:,:-1]
y = train.iloc[:,-1]

# %%
import xgboost as xgb
from xgboost.sklearn import XGBClassifier

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
xgb_model = xgb.XGBClassifier(n_estimators=1000,
                        n_jobs=6,
                        max_depth=5,
                        learning_rate=0.1,
                        gamma = 0,
                        subsample = 0.8,
                        scale_pos_weight = 1,
                        min_child_weight=1,
                        colsample_bytree=0.8,
                        objective= 'binary:logistic',
                        nthread=4,
                        missing=-999,
                        seed=27,
                        tree_method='gpu_hist')

# %%
xgb_model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=-999, n_estimators=1000, n_jobs=6,
#               nthread=4, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=27,
#               silent=None, subsample=0.8, tree_method='gpu_hist', verbosity=1)

# %%
prediction = xgb_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, f1_score

# %%
f1_score(y_test, prediction), accuracy_score(y_test, prediction)
# Out:
# (0.5380832570905763, 0.7109114984074724)

# %%
plt.bar(range(len(xgb_model.feature_importances_)), xgb_model.feature_importances_)
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# # Comparison of Xgboost and Catboost
# result: use catboost

# %%
import catboost as cb

# %%
cb_clf = cb.CatBoostClassifier(task_type = 'GPU')

# %%
# Labelling the categorical features
cat_features= [0,1]

cb_clf.fit(x_train, y_train, cat_features)
# Out:
# Learning rate set to 0.080898
# Warning: less than 75% gpu memory available for training. Free: 4418.375 Total: 6144
# 0:	learn: 0.6749712	total: 38.8ms	remaining: 38.8s
# 1:	learn: 0.6598009	total: 72.6ms	remaining: 36.2s
# 2:	learn: 0.6473672	total: 107ms	remaining: 35.4s
# 3:	learn: 0.6362962	total: 149ms	remaining: 37.2s
# 4:	learn: 0.6272141	total: 189ms	remaining: 37.7s
# 5:	learn: 0.6198647	total: 234ms	remaining: 38.7s
# 6:	learn: 0.6134942	total: 274ms	remaining: 38.9s
# 7:	learn: 0.6080648	total: 316ms	remaining: 39.2s
# 8:	learn: 0.6035102	total: 355ms	remaining: 39.1s
# 9:	learn: 0.5994801	total: 393ms	remaining: 39s
# 10:	learn: 0.5960367	total: 431ms	remaining: 38.8s
# 11:	learn: 0.5932699	total: 473ms	remaining: 38.9s
# 12:	learn: 0.5908400	total: 511ms	remaining: 38.8s
# 13:	learn: 0.5885136	total: 553ms	remaining: 38.9s
# 14:	learn: 0.5863750	total: 584ms	remaining: 38.4s
# 15:	learn: 0.5846179	total: 621ms	remaining: 38.2s
# 16:	learn: 0.5831892	total: 663ms	remaining: 38.3s
# 17:	learn: 0.5817726	total: 700ms	remaining: 38.2s
# 18:	learn: 0.5803720	total: 733ms	remaining: 37.9s
# 19:	learn: 0.5791583	total: 771ms	remaining: 37.8s
# 20:	learn: 0.5780503	total: 809ms	remaining: 37.7s
# 21:	learn: 0.5771987	total: 853ms	remaining: 37.9s
# 22:	learn: 0.5763686	total: 894ms	remaining: 38s
# 23:	learn: 0.5754800	total: 928ms	remaining: 37.7s
# 24:	learn: 0.5747115	total: 963ms	remaining: 37.6s
# 25:	learn: 0.5741104	total: 1s	remaining: 37.6s
# 26:	learn: 0.5734526	total: 1.04s	remaining: 37.5s
# 27:	learn: 0.5729819	total: 1.08s	remaining: 37.5s
# 28:	learn: 0.5724698	total: 1.12s	remaining: 37.5s
# 29:	learn: 0.5718085	total: 1.16s	remaining: 37.4s
# 30:	learn: 0.5713269	total: 1.19s	remaining: 37.3s
# 31:	learn: 0.5708582	total: 1.23s	remaining: 37.2s
# 32:	learn: 0.5704773	total: 1.27s	remaining: 37.2s
# 33:	learn: 0.5700578	total: 1.31s	remaining: 37.3s
# 34:	learn: 0.5697870	total: 1.35s	remaining: 37.3s
# 35:	learn: 0.5693709	total: 1.38s	remaining: 37.1s
# 36:	learn: 0.5689546	total: 1.42s	remaining: 37s
# 37:	learn: 0.5686279	total: 1.45s	remaining: 36.8s
# 740:	learn: 0.5416908	total: 25.1s	remaining: 8.77s
# 741:	learn: 0.5416744	total: 25.1s	remaining: 8.74s
# 742:	learn: 0.5416555	total: 25.2s	remaining: 8.71s
# 743:	learn: 0.5416380	total: 25.2s	remaining: 8.67s
# 744:	learn: 0.5416319	total: 25.2s	remaining: 8.64s
# 745:	learn: 0.5416236	total: 25.3s	remaining: 8.61s
# 746:	learn: 0.5416020	total: 25.3s	remaining: 8.57s
# 747:	learn: 0.5415933	total: 25.4s	remaining: 8.54s
# 748:	learn: 0.5415779	total: 25.4s	remaining: 8.51s
# 749:	learn: 0.5415659	total: 25.4s	remaining: 8.48s
# 750:	learn: 0.5415560	total: 25.5s	remaining: 8.44s
# 751:	learn: 0.5415436	total: 25.5s	remaining: 8.41s
# 752:	learn: 0.5415293	total: 25.5s	remaining: 8.38s
# 753:	learn: 0.5415190	total: 25.6s	remaining: 8.34s
# 754:	learn: 0.5414951	total: 25.6s	remaining: 8.31s
# 755:	learn: 0.5414777	total: 25.6s	remaining: 8.28s
# 756:	learn: 0.5414714	total: 25.7s	remaining: 8.24s
# 757:	learn: 0.5414612	total: 25.7s	remaining: 8.21s
# 758:	learn: 0.5414382	total: 25.7s	remaining: 8.18s
# 759:	learn: 0.5414285	total: 25.8s	remaining: 8.14s
# 760:	learn: 0.5414197	total: 25.8s	remaining: 8.11s
# 761:	learn: 0.5414062	total: 25.9s	remaining: 8.08s
# 762:	learn: 0.5413970	total: 25.9s	remaining: 8.04s
# 763:	learn: 0.5413863	total: 25.9s	remaining: 8.01s
# 764:	learn: 0.5413768	total: 26s	remaining: 7.98s
# 765:	learn: 0.5413672	total: 26s	remaining: 7.95s
# 766:	learn: 0.5413435	total: 26.1s	remaining: 7.91s
# 767:	learn: 0.5413328	total: 26.1s	remaining: 7.88s
# 768:	learn: 0.5413033	total: 26.1s	remaining: 7.85s
# 769:	learn: 0.5412947	total: 26.2s	remaining: 7.82s
# 770:	learn: 0.5412900	total: 26.2s	remaining: 7.78s
# 771:	learn: 0.5412743	total: 26.2s	remaining: 7.75s
# 772:	learn: 0.5412593	total: 26.3s	remaining: 7.72s
# 773:	learn: 0.5412347	total: 26.3s	remaining: 7.68s
# 774:	learn: 0.5412197	total: 26.4s	remaining: 7.65s
# 775:	learn: 0.5412109	total: 26.4s	remaining: 7.62s
# 776:	learn: 0.5412021	total: 26.4s	remaining: 7.59s
# 777:	learn: 0.5411910	total: 26.5s	remaining: 7.55s
# 778:	learn: 0.5411739	total: 26.5s	remaining: 7.52s
# 779:	learn: 0.5411625	total: 26.6s	remaining: 7.49s
# 780:	learn: 0.5411496	total: 26.6s	remaining: 7.46s
# 781:	learn: 0.5411401	total: 26.6s	remaining: 7.43s
# 782:	learn: 0.5411299	total: 26.7s	remaining: 7.4s
# 783:	learn: 0.5411195	total: 26.7s	remaining: 7.36s
# 784:	learn: 0.5411071	total: 26.8s	remaining: 7.33s
# 785:	learn: 0.5410977	total: 26.8s	remaining: 7.3s
# 786:	learn: 0.5410797	total: 26.8s	remaining: 7.26s
# 927:	learn: 0.5392007	total: 32.1s	remaining: 2.49s
# 928:	learn: 0.5391866	total: 32.1s	remaining: 2.45s
# 929:	learn: 0.5391691	total: 32.1s	remaining: 2.42s
# 930:	learn: 0.5391625	total: 32.2s	remaining: 2.38s
# 931:	learn: 0.5391570	total: 32.2s	remaining: 2.35s
# 932:	learn: 0.5391487	total: 32.3s	remaining: 2.32s
# 933:	learn: 0.5391388	total: 32.3s	remaining: 2.28s
# 934:	learn: 0.5391167	total: 32.3s	remaining: 2.25s
# 935:	learn: 0.5391019	total: 32.4s	remaining: 2.21s
# 936:	learn: 0.5390913	total: 32.4s	remaining: 2.18s
# 937:	learn: 0.5390851	total: 32.5s	remaining: 2.15s
# 938:	learn: 0.5390744	total: 32.5s	remaining: 2.11s
# 939:	learn: 0.5390608	total: 32.5s	remaining: 2.08s
# 940:	learn: 0.5390569	total: 32.6s	remaining: 2.04s
# 941:	learn: 0.5390402	total: 32.6s	remaining: 2.01s
# 942:	learn: 0.5390315	total: 32.6s	remaining: 1.97s
# 943:	learn: 0.5390249	total: 32.7s	remaining: 1.94s
# 944:	learn: 0.5390108	total: 32.7s	remaining: 1.9s
# 945:	learn: 0.5389988	total: 32.8s	remaining: 1.87s
# 946:	learn: 0.5389931	total: 32.8s	remaining: 1.83s
# 947:	learn: 0.5389856	total: 32.8s	remaining: 1.8s
# 948:	learn: 0.5389742	total: 32.9s	remaining: 1.77s
# 949:	learn: 0.5389666	total: 32.9s	remaining: 1.73s
# 950:	learn: 0.5389556	total: 33s	remaining: 1.7s
# 951:	learn: 0.5389471	total: 33s	remaining: 1.66s
# 952:	learn: 0.5389348	total: 33s	remaining: 1.63s
# 953:	learn: 0.5389242	total: 33.1s	remaining: 1.59s
# 954:	learn: 0.5389146	total: 33.1s	remaining: 1.56s
# 955:	learn: 0.5389047	total: 33.1s	remaining: 1.52s
# 956:	learn: 0.5388937	total: 33.2s	remaining: 1.49s
# 957:	learn: 0.5388807	total: 33.2s	remaining: 1.46s
# 958:	learn: 0.5388704	total: 33.3s	remaining: 1.42s
# 959:	learn: 0.5388541	total: 33.3s	remaining: 1.39s
# 960:	learn: 0.5388281	total: 33.3s	remaining: 1.35s
# 961:	learn: 0.5388173	total: 33.4s	remaining: 1.32s
# 962:	learn: 0.5388147	total: 33.4s	remaining: 1.28s
# 963:	learn: 0.5388024	total: 33.4s	remaining: 1.25s
# 964:	learn: 0.5387891	total: 33.5s	remaining: 1.21s
# 965:	learn: 0.5387802	total: 33.5s	remaining: 1.18s
# 966:	learn: 0.5387641	total: 33.6s	remaining: 1.15s
# 967:	learn: 0.5387508	total: 33.6s	remaining: 1.11s
# 968:	learn: 0.5387384	total: 33.6s	remaining: 1.08s
# 969:	learn: 0.5387286	total: 33.7s	remaining: 1.04s
# 970:	learn: 0.5387167	total: 33.7s	remaining: 1.01s
# 971:	learn: 0.5387015	total: 33.8s	remaining: 973ms
# 972:	learn: 0.5386931	total: 33.8s	remaining: 938ms
# 973:	learn: 0.5386842	total: 33.8s	remaining: 904ms
# 974:	learn: 0.5386732	total: 33.9s	remaining: 869ms
# 975:	learn: 0.5386561	total: 33.9s	remaining: 834ms
# 976:	learn: 0.5386462	total: 34s	remaining: 800ms
# 977:	learn: 0.5386351	total: 34s	remaining: 765ms
# 978:	learn: 0.5386196	total: 34s	remaining: 730ms
# 979:	learn: 0.5386085	total: 34.1s	remaining: 695ms
# 980:	learn: 0.5385932	total: 34.1s	remaining: 660ms
# 981:	learn: 0.5385786	total: 34.1s	remaining: 626ms
# 982:	learn: 0.5385686	total: 34.2s	remaining: 591ms
# 983:	learn: 0.5385641	total: 34.2s	remaining: 556ms
# 984:	learn: 0.5385464	total: 34.2s	remaining: 521ms
# 985:	learn: 0.5385242	total: 34.3s	remaining: 487ms
# 986:	learn: 0.5385174	total: 34.3s	remaining: 452ms
# 987:	learn: 0.5385060	total: 34.3s	remaining: 417ms
# 988:	learn: 0.5384950	total: 34.4s	remaining: 383ms
# 989:	learn: 0.5384769	total: 34.4s	remaining: 348ms
# 990:	learn: 0.5384709	total: 34.5s	remaining: 313ms
# 991:	learn: 0.5384621	total: 34.5s	remaining: 278ms
# 992:	learn: 0.5384579	total: 34.5s	remaining: 243ms
# 993:	learn: 0.5384380	total: 34.6s	remaining: 209ms
# 994:	learn: 0.5384124	total: 34.6s	remaining: 174ms
# 995:	learn: 0.5384072	total: 34.7s	remaining: 139ms
# 996:	learn: 0.5383874	total: 34.7s	remaining: 104ms
# 997:	learn: 0.5383745	total: 34.7s	remaining: 69.6ms
# 998:	learn: 0.5383571	total: 34.8s	remaining: 34.8ms
# 999:	learn: 0.5383498	total: 34.8s	remaining: 0us

# %%
y_pred = cb_clf.predict(x_test)

# %%
f1_score(y_test, y_pred), accuracy_score(y_test, y_pred)
# Out:
# (0.5373375452565379, 0.7130318863400494)

# %% [markdown]
# # Parameter Tuning
# Parameter will change as the data increases. Catboost automatically sets good initial parameters. Use it instead

# %% [markdown]
# from sklearn.model_selection import RandomizedSearchCV
# from scipy.stats import uniform as sp_randFloat
# from scipy.stats import randint as sp_randInt
# from catboost import CatBoostClassifier

# %% [markdown]
# import warnings
# warnings.filterwarnings("ignore")
#
# model = CatBoostClassifier(task_type = 'GPU')
# parameters = {
#                 'border_count': [13],
#                 'depth': [9],
#                 'learning_rate': [0.015,0.02,0.25],
#                 'iterations': [1500,1600,1700],
#                 'thread_count' : [4]
#              }
#
# randm = RandomizedSearchCV(estimator=model, param_distributions = parameters,
#                            cv = 2, n_iter = 10, n_jobs=-1, scoring='f1')
# randm.fit(x_train, y_train)
#
# # Results from Random Search
# print("\n========================================================")
# print(" Results from Random Search " )
# print("========================================================")
#
# print("\n The best estimator across ALL searched params:\n",
#       randm.best_estimator_)
#
# print("\n The best score across ALL searched params:\n",
#       randm.best_score_)
#
# print("\n The best parameters across ALL searched params:\n",
#       randm.best_params_)
#
# print("\n ========================================================")

# %%
import pickle

filename = 'Non_nlp_model' # name to store model
pickle.dump(cb_clf, open(filename, 'wb')) # pickling
